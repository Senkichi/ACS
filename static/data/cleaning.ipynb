# %%
import requests
import pandas as pd
import numpy as np
from pprint import pprint
import json

# %%
lat_lon = pd.read_csv('final_w_lat_lon.csv', encoding='cp1252')

# %%
lat_lon = lat_lon.drop("Unnamed: 0", axis=1)

# %%
lat_lon['County'] = lat_lon['County'].str.replace(r' .*', '')

# %%
lat_lon
# Out:
#         County  2016IN  2016OUT  2016NET  2015IN  2015OUT  2015NET  2014IN  \
# 0      Alameda  113013    93326     -167  108017    89267      960  103183
# 1       Alpine     160      110       42     183      253      -82     165
# 2       Amador    3724     2868      806    3493     2700      724    2896
# 3        Butte   14982    12840     1433   13463    12349      339   13296
# 4    Calaveras    2393     2583     -243    2148     2452     -353    2023
# 5       Colusa     698     1445     -807     635     1266     -717     576
# 6       Contra   66721    49837     8139   63410    46755     7910   61158
# 7          Del    2538     2431       80    2806     2631      132    2863
# 8           El   11187    11786    -1084    9543    10904    -1985    8899
# 9       Fresno   35098    31067     -438   35814    31075      598   32931
# 10       Glenn    1249     1765     -589    1192     1546     -439    1256
# ...

# %%
# Out:
#     Unnamed: 0                              County  2016IN  2016OUT  2016NET  \
# 0            0          Alameda County, California  113013    93326     -167
# 1            1           Alpine County, California     160      110       42
# 2            2           Amador County, California    3724     2868      806
# 3            3            Butte County, California   14982    12840     1433
# 4            4        Calaveras County, California    2393     2583     -243
# 5            5           Colusa County, California     698     1445     -807
# 6            6     Contra Costa County, California   66721    49837     8139
# 7            7        Del Norte County, California    2538     2431       80
# 8            8        El Dorado County, California   11187    11786    -1084
# 9            9           Fresno County, California   35098    31067     -438
# 10          10            Glenn County, California    1249     1765     -589
# ...
